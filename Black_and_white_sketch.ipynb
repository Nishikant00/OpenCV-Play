# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %% [markdown]
# Inserting a image in this function

# %%
##insert image path in this single quotation mark
img=cv2.imread('demo-image.jpg')

# %%
img
# Out:
# array([[[ 37, 102,  77],
#         [ 59, 124,  99],
#         [ 98, 160, 136],
#         ...,
#         [ 37,  93,  72],
#         [ 43,  99,  78],
#         [ 43,  99,  78]],
#
#        [[ 41,  99,  75],
#         [ 46, 104,  80],
#         [ 71, 129, 105],
#         ...,
#         [ 48, 104,  83],
#         [ 40,  96,  75],
#         [ 33,  89,  68]],
#
#        [[ 43,  97,  74],
#         [ 58, 112,  89],
#         [ 59, 115,  92],
#         ...,
#         [ 58, 114,  93],
#         [ 52, 108,  87],
#         [ 49, 105,  84]],
#
#        ...,
#
#        [[ 44, 106,  84],
#         [ 64, 123, 102],
#         [ 81, 134, 114],
#         ...,
#         [ 57, 109,  92],
#         [ 36,  88,  71],
#         [ 44,  93,  77]],
#
#        [[ 61, 123, 101],
#         [ 22,  79,  58],
#         [ 51, 104,  84],
#         ...,
#         [ 62, 114,  97],
#         [ 55, 107,  90],
#         [ 39,  88,  72]],
#
#        [[ 87, 146, 125],
#         [ 47, 104,  83],
#         [ 25,  78,  58],
#         ...,
#         [ 70, 124, 107],
#         [ 37,  91,  74],
#         [ 33,  85,  68]]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=375x500 at 0x7FA7CB2DEF90>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[ 87, 109, 146, ...,  80,  86,  86],
#        [ 85,  90, 115, ...,  91,  83,  76],
#        [ 84,  99, 102, ..., 101,  95,  92],
#        ...,
#        [ 92, 110, 122, ...,  98,  77,  83],
#        [109,  66,  92, ..., 103,  96,  78],
#        [133,  91,  66, ..., 113,  80,  74]], dtype=uint8)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7FA7CB3ABE50>

# %%
invert=cv2.bitwise_not(gray)

# %%
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7FA7CB39C8D0>

# %%
smoothing=cv2.GaussianBlur(invert,(21,21),sigmaX=0,sigmaY=0)

# %%
def dodging(x,y):
  return cv2.divide(x,255-y,scale=256)

# %%
final=dodging(gray,smoothing)

# %%
cv2_imshow(final)
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7FA7CB3C5190>
